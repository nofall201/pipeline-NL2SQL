# %%
# === IMPORT LIBRARY ===
import os
import pandas as pd
import psycopg2
from vanna.ollama import Ollama
from vanna.chromadb import ChromaDB_VectorStore

# === SETUP PATH ===
cdir = os.getcwd()
chroma = os.path.join(cdir, "database")
training_csv = os.path.join(cdir, "training", "dataset.csv")

# === CLASS VNANNA: COMBINE OLLAMA + CHROMADB ===
class Vanna(ChromaDB_VectorStore, Ollama):
    def __init__(self, config=None) -> None:
        ChromaDB_VectorStore.__init__(self, config=config)
        Ollama.__init__(self, config=config)

# === INSTANSIASI MODEL OLLAMA + CHROMA ===
print("🚀 Inisialisasi Vanna dengan model dan ChromaDB...")
vn = Vanna(
    config={
        "model": "qwen2.5:3b",
        "path": chroma,
    }
)
print("✅ Vanna siap!")

# === GANTI FUNGSI RUN_SQL DENGAN VERSI MANUAL (psycopg2) ===
def manual_run_sql(sql: str) -> pd.DataFrame:
    try:
        conn = psycopg2.connect(
            host="localhost",
            port=5433,
            user="postgres",
            password="KuRn1@26",
            dbname="data_telkomsel"
        )
        df = pd.read_sql_query(sql, conn)
        conn.close()
        return df
    except Exception as e:
        print("❌ Error pada manual_run_sql:", e)
        return pd.DataFrame()

vn.run_sql = manual_run_sql  # Override default run_sql()

# === TRAINING DARI DDL (schema/tabel di PostgreSQL) + COMMENT ===
try:
    print("🔍 Mengambil daftar tabel dari PostgreSQL...")
    ddls = vn.run_sql("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';")

    if ddls.empty:
        print("⚠️ Tidak ada tabel ditemukan.")
    else:
        print(f"📋 Ditemukan {len(ddls)} tabel:", ddls["table_name"].tolist())

        for table_name in ddls["table_name"]:
            print(f"📦 Memproses tabel: {table_name}...")

            # Ambil DDL utama
            ddl_query = f"""
            SELECT 'CREATE TABLE {table_name} (\n' ||
                   string_agg('    ' || a.attname || ' ' || format_type(a.atttypid, a.atttypmod), ',\n') ||
                   '\n);' AS ddl
            FROM pg_class c
            JOIN pg_attribute a ON a.attrelid = c.oid
            WHERE c.relname = '{table_name}' AND a.attnum > 0 AND NOT a.attisdropped;
            """
            ddl_result = vn.run_sql(ddl_query)

            # Ambil komentar kolom
            col_comment_query = f"""
            SELECT a.attname AS column_name, d.description AS comment
            FROM pg_class c
            JOIN pg_attribute a ON a.attrelid = c.oid
            LEFT JOIN pg_description d ON d.objoid = a.attrelid AND d.objsubid = a.attnum
            WHERE c.relname = '{table_name}' AND a.attnum > 0 AND NOT a.attisdropped;
            """
            col_comments = vn.run_sql(col_comment_query)

            # Ambil komentar tabel
            tbl_comment_query = f"""
            SELECT d.description AS comment
            FROM pg_class c
            LEFT JOIN pg_description d ON d.objoid = c.oid AND d.objsubid = 0
            WHERE c.relname = '{table_name}';
            """
            tbl_comment = vn.run_sql(tbl_comment_query)

            if not ddl_result.empty:
                ddl_base = ddl_result.iloc[0, 0]
                comment_block = f"-- DDL for table `{table_name}`\n"

                if not tbl_comment.empty and pd.notnull(tbl_comment.iloc[0, 0]):
                    comment_block += f"-- Table comment: {tbl_comment.iloc[0, 0]}\n"

                if not col_comments.empty:
                    for _, row in col_comments.iterrows():
                        if pd.notnull(row["comment"]):
                            comment_block += f"-- Column `{row['column_name']}`: {row['comment']}\n"

                final_ddl = comment_block + ddl_base
                vn.train(ddl=final_ddl)
                print(f"✅ Training DDL + COMMENT sukses untuk tabel: {table_name}")
            else:
                print(f"⚠️ DDL kosong untuk tabel: {table_name}")

except Exception as e:
    print("❌ Gagal saat training DDL + COMMENT:", e)

# === TRAINING DARI CSV Q&A ===
try:
    print("📥 Membaca file training CSV...")
    df = pd.read_csv(training_csv, delimiter=";", encoding="utf-8")

    if df.empty or "question" not in df.columns or "answer" not in df.columns:
        raise ValueError("CSV kosong atau kolom 'question' / 'answer' tidak ditemukan.")

    print(f"✅ CSV dibaca, {len(df)} baris ditemukan.")

    for index, row in df.iterrows():
        question = str(row["question"]).strip()
        answer = str(row["answer"]).strip() + ";"
        try:
            vn.train(question=question, sql=answer)
            print(f"✅ Q{index+1}: Training berhasil — \"{question}\"")
        except Exception as e:
            print(f"❌ Q{index+1}: Gagal training — \"{question}\" | Error: {e}")
except Exception as e:
    print("❌ Gagal membaca atau memproses CSV:", e)
# Out:
# 🚀 Inisialisasi Vanna dengan model dan ChromaDB...
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# ✅ Vanna siap!
# 🔍 Mengambil daftar tabel dari PostgreSQL...
# C:\Users\rafi\AppData\Local\Temp\ipykernel_25416\1504409858.py:39: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn)
# 📋 Ditemukan 1 tabel: ['data_performance']
# 📦 Memproses tabel: data_performance...
# Adding ddl: -- DDL for table `data_performance`
# -- Table comment: Tabel "data_performance" menyimpan data transaksi harian dari berbagai channel penjualan Telkomsel. Tabel ini digunakan untuk menganalisis performa penjualan berdasarkan dimensi waktu (`trx_date`), wilayah (`region`, `area`), produk (`product_commercial_name`), kampanye pemasaran (`campaign_initiatives`), channel distribusi (`channel_name`), dan metode pembayaran (`payment_method`). Data mencakup metrik utama seperti jumlah transaksi (`trx`), total pendapatan (`revenue`), dan jumlah pengguna unik (`taker_uniq_all`). Tabel ini penting untuk pelaporan, evaluasi kampanye, dan pengambilan keputusan berbasis data. Query terhadap tabel ini akan menggunakan sintaks PostgreSQL.
# -- Column `trx_date`: Tanggal terjadinya transaksi.
# -- Column `groups`: Segmentasi pelanggan berdasarkan tahap campaign seperti Conversion atau Retention
# -- Column `area`: Area operasional di dalam region tempat transaksi terjadi.
# -- Column `region`: Klasifikasi wilayah transaksi:
# - 00.Unknown = Wilayah tidak teridentifikasi,
# - 01.Sumbagut = Sumatera bagian utara,
# - 02.Sumbagteng = Sumatera bagian tengah,
# - 03.Sumbagsel = Sumatera bagian selatan,
# - 04.Western Jabotabek = Wilayah barat Jabotabek, mencakup Jakarta Barat, Tangerang, dan sebagian Bogor,
# - 05.Central Jabotabek = Wilayah tengah Jabotabek, mencakup Jakarta Pusat dan sebagian Depok/Bogor,
# - 06.Eastern Jabotabek = Wilayah timur Jabotabek, mencakup Jakarta Timur, Bekasi, dan sekitarnya,
# - 07.Jabar = Provinsi Jawa Barat (di luar area Jabotabek),
# - 08.Jateng = Provinsi Jawa Tengah,
# - 09.Jatim = Provinsi Jawa Timur,
# - 10.Balinusra = Bali dan Nusa Tenggara,
# - 11.Kalimantan = Pulau Kalimantan (seluruh provinsi),
# - 12.Sulawesi = Pulau Sulawesi (seluruh provinsi),
# - 13.Puma = Papua dan Maluku,
# - Others = Wilayah lain yang tidak terklasifikasi secara spesifik.
# -- Column `campaign_initiatives`: Nama inisiatif atau kampanye pemasaran yang dikaitkan dengan transaksi.
# -- Column `product_commercial_name`: Nama produk komersial yang dibeli oleh pelanggan.
# -- Column `channel_name`: Channel penjualan:
# - 01.MyTelkomsel = Aplikasi resmi Telkomsel,
# - 02.UMB = USSD Menu Browser (akses melalui *888#),
# - 03.SMS 5111 = Layanan pembelian melalui SMS ke 5111,
# - 04.WABA = Akun WhatsApp Business resmi Telkomsel,
# - 05.DigiPos = Aplikasi DigiPos Aja! untuk reseller/mitra outlet,
# - 06.Modern Channel = Channel ritel modern seperti Alfamart dan Indomaret,
# - Others = Channel lainnya yang tidak termasuk kategori di atas.
# -- Column `payment_method`: Metode pembayaran yang digunakan untuk transaksi:
# - BALANCE = Saldo prabayar pelanggan,
# - BNI_DD = Debit langsung Bank Negara Indonesia,
# - BRI_DD = Debit langsung Bank Rakyat Indonesia,
# - DANA = Dompet digital DANA,
# - FINNET_CC = Kartu kredit melalui Finnet,
# - FINNET_VA = Virtual account melalui Finnet,
# - GOPAY = Dompet digital GoPay,
# - KREDIVO = Pembayaran cicilan melalui Kredivo,
# - LINKAJA_APP = LinkAja melalui aplikasi,
# - LINKAJA_WCO = LinkAja melalui Web Checkout,
# - LOAN = Pembayaran berbasis pembiayaan/pinjaman,
# - MANDIRI_DD = Debit langsung Bank Mandiri,
# - OVO = Dompet digital OVO,
# - RSEMONEY = Saldo internal Telkomsel (uang),
# - RSSTOCK = Saldo internal Telkomsel (stok),
# - SHOPEEPAY = Dompet digital ShopeePay,
# - TSEL_PAYLATER = Layanan Telkomsel PayLater,
# - TSEL_WALLET = Dompet digital Telkomsel.
# -- Column `taker_uniq_all`: Jumlah pengguna unik yang melakukan pembelian pada hari tersebut.
# -- Column `revenue`: Total pendapatan (revenue) yang dihasilkan dari transaksi.
# -- Column `trx`: Jumlah transaksi yang terjadi pada tanggal tersebut.
# CREATE TABLE data_performance (
#     trx_date date,
#     groups text,
#     area text,
#     region text,
#     campaign_initiatives text,
#     product_commercial_name text,
#     channel_name text,
#     payment_method text,
#     taker_uniq_all bigint,
#     revenue bigint,
#     trx bigint
# );
# Failed to send telemetry event CollectionAddEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event CollectionAddEvent: capture() takes 1 positional argument but 3 were given
# ✅ Training DDL + COMMENT sukses untuk tabel: data_performance
# 📥 Membaca file training CSV...
# ✅ CSV dibaca, 542 baris ditemukan.
# ✅ Q1: Training berhasil — "Bagaimana perubahan total revenue dari bulan Desember 2024 ke Januari 2025 di setiap region?"
# ✅ Q2: Training berhasil — "Bandingkan jumlah taker unik untuk bulan Januari 2025 dan Februari 2025 di setiap region"
# ✅ Q3: Training berhasil — "Berapa selisih transaksi antara bulan Desember 2024 dan Januari 2025 untuk tiap-tiap area?"
# ✅ Q4: Training berhasil — "Region mana yang mengalami peningkatan revenue tertinggi dari bulan Januari ke Februari 2025?"
# ✅ Q5: Training berhasil — "Apa perbandingan total transaksi antara region Jateng dan Jatim pada bulan Februari 2025?"
# ✅ Q6: Training berhasil — "Tampilkan perbedaan revenue antara bulan Januari 2025 dan Februari 2025 untuk setiap channel"
# ✅ Q7: Training berhasil — "Bagaimana pertumbuhan taker unik di region Kalimantan dari bulan Desember 2024 ke Januari 2025?"
# ✅ Q8: Training berhasil — "Bandingkan rata-rata revenue per transaksi untuk bulan Desember 2024 dan Januari 2025"
# ✅ Q9: Training berhasil — "Area mana yang mengalami penurunan jumlah taker unik dari Januari ke Februari 2025?"
# ✅ Q10: Training berhasil — "Bandingkan revenue untuk produk "NonRGB ATL 12GB 7Hari Rp23K" antara bulan Desember 2024 dan Januari 2025"
# ✅ Q11: Training berhasil — "Region mana yang paling konsisten memiliki jumlah transaksi tinggi selama Desember 2024 hingga Februari 2025?"
# ✅ Q12: Training berhasil — "Apakah revenue meningkat dari bulan Januari ke Februari 2025 untuk channel MyTelkomsel?"
# ✅ Q13: Training berhasil — "Tampilkan channel dengan penurunan taker terbanyak dari Januari ke Februari 2025"
# ✅ Q14: Training berhasil — "Bandingkan transaksi di area AREA 2 antara bulan Januari dan Februari 2025"
# ✅ Q15: Training berhasil — "Bagaimana perubahan taker unik untuk campaign "Farming Sachet" dari bulan Desember 2024 ke Januari 2025?"
# ✅ Q16: Training berhasil — "Apa selisih revenue antar channel pada bulan Februari 2025?"
# ✅ Q17: Training berhasil — "Perbandingan jumlah transaksi untuk metode pembayaran BALANCE antara Desember 2024 dan Januari 2025"
# ✅ Q18: Training berhasil — "Channel apa yang mengalami peningkatan revenue paling besar dari Januari ke Februari 2025?"
# ✅ Q19: Training berhasil — "Apa perbandingan total revenue antar channel untuk bulan Desember 2024 dan Januari 2025?"
# ✅ Q20: Training berhasil — "Bandingkan transaksi antara channel DigiPos dan MyTelkomsel di bulan Januari 2025"
# ✅ Q21: Training berhasil — "Apakah jumlah taker menurun untuk produk "NonRGB ATL 2GB 3Hari Rp5K" dari Januari ke Februari 2025?"
# ✅ Q22: Training berhasil — "Tampilkan pertumbuhan transaksi bulanan untuk produk "NonRGB ATL 12GB 7Hari Rp23K" dari Desember 2024 sampai Februari 2025"
# ✅ Q23: Training berhasil — "Apakah ada peningkatan revenue di region Sulawesi dari bulan Januari ke Februari 2025?"
# ✅ Q24: Training berhasil — "Bagaimana tren jumlah taker di region Puma dari Desember 2024 hingga Februari 2025?"
# ✅ Q25: Training berhasil — "Bandingkan total revenue untuk campaign "Farming Sachet" pada bulan Desember 2024 dan Februari 2025"
# ✅ Q26: Training berhasil — "Bagaimana perbandingan total revenue antara bulan Desember 2024 dan Januari 2025?"
# ✅ Q27: Training berhasil — "Bagaimana perubahan jumlah taker unik dari bulan Januari 2025 ke Februari 2025?"
# ✅ Q28: Training berhasil — "Apakah transaksi di region Sulawesi meningkat dari bulan Desember 2024 ke Januari 2025?"
# ✅ Q29: Training berhasil — "Bagaimana perubahan revenue di region Kalimantan antara bulan Januari dan Februari 2025?"
# ✅ Q30: Training berhasil — "Region mana yang mengalami penurunan revenue dari Januari ke Februari 2025?"
# ✅ Q31: Training berhasil — "Apakah jumlah transaksi di Jawa Timur naik dari bulan Desember 2024 ke Januari 2025?"
# ✅ Q32: Training berhasil — "Bandingkan jumlah taker unik pada bulan Januari dan Maret 2025 untuk area AREA 3"
# ✅ Q33: Training berhasil — "Bagaimana perkembangan revenue channel DigiPos dari bulan Desember 2024 hingga Maret 2025?"
# ✅ Q34: Training berhasil — "Apakah terjadi peningkatan transaksi di region Jateng antara bulan Januari dan Februari 2025?"
# ✅ Q35: Training berhasil — "Bandingkan jumlah revenue dan transaksi untuk bulan Februari dan Maret 2025 di channel MyTelkomsel"
# ✅ Q36: Training berhasil — "Bagaimana tren revenue untuk produk NonRGB ATL 7GB 7Hari Rp20K dari Januari sampai Maret 2025?"
# ✅ Q37: Training berhasil — "Region mana yang mencatatkan revenue tertinggi pada bulan Januari 2025 dibanding Februari 2025?"
# ✅ Q38: Training berhasil — "Apakah terjadi penurunan jumlah taker unik di channel UMB dari Februari ke Maret 2025?"
# ✅ Q39: Training berhasil — "Bandingkan revenue untuk metode pembayaran BALANCE dan FINNET_VA pada Januari 2025"
# ✅ Q40: Training berhasil — "Bagaimana pertumbuhan transaksi untuk campaign Farming Sachet dari Desember 2024 ke Januari 2025?"
# ✅ Q41: Training berhasil — "Apakah revenue di area AREA 2 lebih tinggi di bulan Februari 2025 dibanding Januari 2025?"
# ✅ Q42: Training berhasil — "Channel apa yang memiliki peningkatan revenue paling signifikan dari Januari ke Februari 2025?"
# ✅ Q43: Training berhasil — "Bagaimana perbandingan taker unik untuk produk NonRGB ATL 2GB 3Hari Rp5K antara Januari dan Februari 2025?"
# ✅ Q44: Training berhasil — "Apakah transaksi di region Kalimantan lebih banyak di Maret 2025 dibanding Februari 2025?"
# ✅ Q45: Training berhasil — "Bandingkan total revenue nasional pada bulan Januari dan Februari 2025"
# ✅ Q46: Training berhasil — "Bagaimana perbandingan total revenue antara bulan Desember dua ribu dua puluh empat dan Januari dua ribu dua puluh lima?"
# ✅ Q47: Training berhasil — "Berapa selisih jumlah transaksi antara Januari dan Februari dua ribu dua puluh lima?"
# ✅ Q48: Training berhasil — "Mana yang memiliki revenue lebih tinggi: bulan Desember dua ribu dua puluh empat atau Maret dua ribu dua puluh lima?"
# ✅ Q49: Training berhasil — "Bandingkan rata-rata transaksi per region antara bulan Januari dan Februari dua ribu dua puluh lima"
# ✅ Q50: Training berhasil — "Apa selisih jumlah pengguna unik (taker) antara bulan Desember dua ribu dua puluh empat dan Januari dua ribu dua puluh lima?"
# ✅ Q51: Training berhasil — "Berapa total revenue untuk masing-masing region pada bulan Februari dua ribu dua puluh lima dan Maret dua ribu dua puluh lima?"
# ✅ Q52: Training berhasil — "Bandingkan revenue antara area AREA 1 dan AREA 2 di bulan Januari dua ribu dua puluh lima"
# ✅ Q53: Training berhasil — "Bagaimana perubahan jumlah transaksi di region Jatim antara bulan Januari dan Maret dua ribu dua puluh lima?"
# ✅ Q54: Training berhasil — "Apakah revenue di bulan Februari dua ribu dua puluh lima lebih tinggi dari Januari?"
# ✅ Q55: Training berhasil — "Bandingkan jumlah taker untuk produk "NonRGB ATL 12GB 7Hari Rp23K" antara bulan Desember dua ribu dua puluh empat dan Februari dua ribu dua puluh lima"
# ✅ Q56: Training berhasil — "Region mana yang mengalami penurunan revenue dari Januari ke Februari dua ribu dua puluh lima?"
# ✅ Q57: Training berhasil — "Area mana yang memiliki pertumbuhan jumlah taker paling tinggi dari Desember ke Januari?"
# ✅ Q58: Training berhasil — "Bandingkan total transaksi untuk region Sumbagut dan Kalimantan pada Februari dua ribu dua puluh lima"
# ✅ Q59: Training berhasil — "Apakah channel DigiPos mengalami peningkatan revenue dari Januari ke Februari dua ribu dua puluh lima?"
# ✅ Q60: Training berhasil — "Bandingkan rata-rata revenue per transaksi antara bulan Januari dan Maret dua ribu dua puluh lima"
# ✅ Q61: Training berhasil — "Berapa peningkatan jumlah transaksi dari Desember dua ribu dua puluh empat ke Januari dua ribu dua puluh lima?"
# ✅ Q62: Training berhasil — "Mana yang memiliki lebih banyak taker: Januari atau Februari dua ribu dua puluh lima?"
# ✅ Q63: Training berhasil — "Berapa total revenue yang dihasilkan oleh produk "NonRGB ATL 2GB 3Hari Rp5K" di Januari dan Februari dua ribu dua puluh lima?"
# ✅ Q64: Training berhasil — "Bandingkan revenue antar area untuk bulan Februari dua ribu dua puluh lima"
# ✅ Q65: Training berhasil — "Apakah area AREA 3 mengalami penurunan transaksi dari Januari ke Februari dua ribu dua puluh lima?"
# ✅ Q66: Training berhasil — "Region mana yang memiliki peningkatan revenue paling tinggi dari Desember ke Januari?"
# ✅ Q67: Training berhasil — "Bandingkan total transaksi untuk metode pembayaran BALANCE antara Januari dan Maret dua ribu dua puluh lima"
# ✅ Q68: Training berhasil — "Apakah revenue di bulan Maret dua ribu dua puluh lima lebih besar dari rata-rata dua bulan sebelumnya?"
# ✅ Q69: Training berhasil — "Berapa perbedaan jumlah taker antara Januari dan Maret dua ribu dua puluh lima?"
# ✅ Q70: Training berhasil — "Bagaimana perubahan total revenue dari Desember 2024 ke Januari 2025?"
# ✅ Q71: Training berhasil — "Berapa persen kenaikan transaksi dari Januari ke Februari 2025?"
# ✅ Q72: Training berhasil — "Apa perubahan jumlah taker dari Februari ke Maret 2025?"
# ✅ Q73: Training berhasil — "Region mana yang mengalami penurunan revenue terbesar dari Januari ke Februari 2025?"
# ✅ Q74: Training berhasil — "Bandingkan total transaksi antara bulan Desember 2024 dan Januari 2025 per region"
# ✅ Q75: Training berhasil — "Tampilkan persentase perubahan revenue per region dari Februari ke Maret 2025"
# ✅ Q76: Training berhasil — "Bandingkan jumlah taker unik pada bulan Januari dan Februari 2025 per region"
# ✅ Q77: Training berhasil — "Area mana yang menunjukkan pertumbuhan revenue tertinggi dari Desember 2024 ke Januari 2025?"
# ✅ Q78: Training berhasil — "Berapa perbandingan total revenue antara Januari dan Maret 2025 di seluruh area?"
# ✅ Q79: Training berhasil — "Region mana yang konsisten mengalami kenaikan transaksi dari Desember 2024 hingga Maret 2025?"
# ✅ Q80: Training berhasil — "Tampilkan selisih revenue bulan Maret dan Februari 2025 per region"
# ✅ Q81: Training berhasil — "Berapa persen kenaikan taker unik di Jateng dari Januari ke Maret 2025?"
# ✅ Q82: Training berhasil — "Bandingkan total transaksi untuk Kalimantan dan Sulawesi selama Januari 2025"
# ✅ Q83: Training berhasil — "Tampilkan perubahan revenue channel DigiPos antara Desember 2024 dan Maret 2025"
# ✅ Q84: Training berhasil — "Berapa perubahan revenue di Jawa Timur antara Januari dan Februari 2025?"
# ✅ Q85: Training berhasil — "Bandingkan total transaksi antara channel MyTelkomsel dan UMB pada bulan Februari 2025"
# ✅ Q86: Training berhasil — "Tampilkan pertumbuhan rata-rata revenue per taker dari Januari ke Februari 2025"
# ✅ Q87: Training berhasil — "Bandingkan revenue per region antara Januari dan Maret 2025"
# ✅ Q88: Training berhasil — "Apa region dengan penurunan taker unik tertinggi dari Februari ke Maret 2025?"
# ✅ Q89: Training berhasil — "Bandingkan jumlah transaksi per area antara bulan Desember 2024 dan Maret 2025"
# ✅ Q90: Training berhasil — "Berapa selisih revenue antara Februari dan Maret 2025 di region Eastern Jabotabek?"
# ✅ Q91: Training berhasil — "Berapa persen perubahan transaksi di Sulawesi dari Desember 2024 ke Maret 2025?"
# ✅ Q92: Training berhasil — "Bagaimana perbandingan total revenue antara bulan Januari dan Februari tahun 2025 di seluruh region?"
# ✅ Q93: Training berhasil — "Berapa selisih jumlah taker unik antara bulan Desember 2024 dan Januari 2025 untuk setiap region?"
# ✅ Q94: Training berhasil — "Di region mana terjadi penurunan transaksi terbesar dari bulan Januari ke Februari tahun 2025?"
# ✅ Q95: Training berhasil — "Bandingkan revenue antara channel DigiPos dan MyTelkomsel pada bulan Maret tahun 2025."
# ✅ Q96: Training berhasil — "Berapa persen kenaikan revenue di region Jatim dari Desember 2024 ke Januari 2025?"
# ✅ Q97: Training berhasil — "Bagaimana pertumbuhan jumlah taker unik dari bulan Februari ke Maret tahun 2025 di area AREA 1?"
# ✅ Q98: Training berhasil — "Bandingkan transaksi di seluruh area pada bulan Januari dan Februari tahun 2025."
# ✅ Q99: Training berhasil — "Berapa total revenue untuk campaign Farming Sachet di bulan Desember 2024 dan Januari 2025?"
# ✅ Q100: Training berhasil — "Channel mana yang memiliki penurunan revenue tertinggi dari Januari ke Februari tahun 2025?"
# ✅ Q101: Training berhasil — "Berapa rata-rata revenue per transaksi pada bulan Maret tahun 2025?"
# ✅ Q102: Training berhasil — "Bagaimana distribusi revenue di setiap region pada bulan Desember 2024 dan Januari 2025?"
# ✅ Q103: Training berhasil — "Bandingkan jumlah taker unik antara channel UMB dan MyTelkomsel di bulan Februari tahun 2025."
# ✅ Q104: Training berhasil — "Area mana yang mengalami peningkatan transaksi tertinggi dari Desember 2024 ke Januari 2025?"
# ✅ Q105: Training berhasil — "Berapa selisih revenue antara area AREA 1 dan AREA 2 di bulan Maret 2025?"
# ✅ Q106: Training berhasil — "Bagaimana perkembangan taker unik di seluruh channel dari Januari ke Maret 2025?"
# ✅ Q107: Training berhasil — "Berapa persen perubahan transaksi dari Februari ke Maret tahun 2025 untuk region 07.Jabar?"
# ✅ Q108: Training berhasil — "Berapa transaksi yang terjadi di bulan Desember 2024 dan Maret 2025 untuk campaign tertentu?"
# ✅ Q109: Training berhasil — "Bandingkan revenue channel DigiPos antara bulan Januari dan Februari tahun 2025."
# ✅ Q110: Training berhasil — "Region mana yang stabil dalam jumlah taker dari bulan Desember ke Januari?"
# ✅ Q111: Training berhasil — "Apakah channel UMB mengalami pertumbuhan revenue dari Januari ke Februari 2025?"
# ✅ Q112: Training berhasil — "Berapa rata-rata revenue per taker pada Februari tahun 2025?"
# ✅ Q113: Training berhasil — "Bagaimana tren transaksi di channel MyTelkomsel dari Desember 2024 hingga Maret 2025?"
# ✅ Q114: Training berhasil — "Berapa selisih revenue untuk campaign Farming Sachet antara Januari dan Maret 2025?"
# ✅ Q115: Training berhasil — "Bandingkan transaksi antara region 01.Sumbagut dan 09.Jatim pada bulan Februari 2025."
# ✅ Q116: Training berhasil — "Tampilkan total revenue untuk setiap region selama bulan Desember 2024"
# ✅ Q117: Training berhasil — "Berapa jumlah transaksi per metode pembayaran di bulan Januari 2025?"
# ✅ Q118: Training berhasil — "Tampilkan total revenue dari masing-masing produk untuk campaign Bundling Combo di bulan Maret 2025"
# ✅ Q119: Training berhasil — "Bandingkan revenue di bulan Januari 2025 dan Februari 2025 untuk setiap region"
# ✅ Q120: Training berhasil — "Berapa banyak pengguna unik untuk setiap produk yang dibeli di bulan Februari 2025?"
# ✅ Q121: Training berhasil — "Tampilkan total transaksi untuk masing-masing channel di bulan Desember 2024"
# ✅ Q122: Training berhasil — "Perbandingan revenue masing-masing area antara bulan Januari dan Maret 2025"
# ✅ Q123: Training berhasil — "Berapa total transaksi yang dilakukan melalui setiap channel untuk campaign Farming Sachet?"
# ✅ Q124: Training berhasil — "Tampilkan jumlah revenue dan jumlah transaksi per metode pembayaran di bulan Februari 2025"
# ✅ Q125: Training berhasil — "Bandingkan pengguna unik antara dua produk populer di bulan Januari 2025"
# ✅ Q126: Training berhasil — "Berapa total revenue masing-masing campaign pada bulan Desember 2024?"
# ✅ Q127: Training berhasil — "Tampilkan total transaksi masing-masing produk untuk channel MyTelkomsel"
# ✅ Q128: Training berhasil — "Bandingkan revenue tiap region antara bulan Desember 2024 dan Februari 2025"
# ✅ Q129: Training berhasil — "Tampilkan transaksi per area untuk produk NonRGB ATL 2GB 3Hari Rp5K di bulan Januari 2025"
# ✅ Q130: Training berhasil — "Berapa total revenue untuk masing-masing metode pembayaran di bulan Maret 2025?"
# ✅ Q131: Training berhasil — "Tampilkan taker unik masing-masing area untuk bulan Februari 2025"
# ✅ Q132: Training berhasil — "Perbandingan revenue antar channel untuk produk NonRGB ATL 12GB 7Hari Rp23K"
# ✅ Q133: Training berhasil — "Tampilkan perbandingan revenue region di bulan Desember 2024 dan Januari 2025"
# ✅ Q134: Training berhasil — "Berapa total transaksi untuk setiap area di bulan Desember 2024?"
# ✅ Q135: Training berhasil — "Tampilkan revenue masing-masing channel untuk campaign Bundling Combo di bulan Februari 2025"
# ✅ Q136: Training berhasil — "Bandingkan pengguna unik antar region untuk bulan Januari 2025"
# ✅ Q137: Training berhasil — "Tampilkan revenue dan taker unik masing-masing produk di bulan Maret 2025"
# ✅ Q138: Training berhasil — "Berapa total transaksi untuk setiap metode pembayaran di bulan Januari 2025?"
# ✅ Q139: Training berhasil — "Bandingkan total revenue antar area untuk campaign Farming Sachet"
# ✅ Q140: Training berhasil — "Tampilkan jumlah pengguna unik dari setiap channel di bulan Februari 2025"
# ✅ Q141: Training berhasil — "Bagaimana perbandingan total revenue antara bulan Desember dua ribu dua puluh empat dan Januari dua ribu dua puluh lima?"
# ✅ Q142: Training berhasil — "Tampilkan total revenue per region untuk bulan Januari dua ribu dua puluh lima."
# ✅ Q143: Training berhasil — "Tampilkan jumlah transaksi per channel_name selama bulan Februari dua ribu dua puluh lima."
# ✅ Q144: Training berhasil — "Berapa total revenue di setiap area pada bulan Maret dua ribu dua puluh lima?"
# ✅ Q145: Training berhasil — "Tampilkan jumlah pengguna unik (taker_uniq_all) untuk setiap channel di bulan Desember dua ribu dua puluh empat."
# ✅ Q146: Training berhasil — "Bagaimana tren revenue bulanan dari Desember dua ribu dua puluh empat hingga Maret dua ribu dua puluh lima?"
# ✅ Q147: Training berhasil — "Tampilkan perbandingan jumlah transaksi di setiap region selama bulan Februari dua ribu dua puluh lima."
# ✅ Q148: Training berhasil — "Berapa total revenue dari masing-masing payment_method di bulan Januari dua ribu dua puluh lima?"
# ✅ Q149: Training berhasil — "Bandingkan jumlah transaksi antara area AREA 1 dan AREA 2 selama bulan Desember dua ribu dua puluh empat."
# ✅ Q150: Training berhasil — "Berapa total taker_uniq_all yang membeli produk per bulan sepanjang Januari hingga Maret dua ribu dua puluh lima?"
# ✅ Q151: Training berhasil — "Tampilkan top 5 produk berdasarkan revenue tertinggi pada bulan Desember dua ribu dua puluh empat."
# ✅ Q152: Training berhasil — "Berapa total transaksi per payment_method untuk bulan Maret dua ribu dua puluh lima?"
# ✅ Q153: Training berhasil — "Bagaimana distribusi revenue berdasarkan channel_name di bulan Februari dua ribu dua puluh lima?"
# ✅ Q154: Training berhasil — "Tampilkan total revenue dan jumlah transaksi dari masing-masing area di bulan Januari dua ribu dua puluh lima."
# ✅ Q155: Training berhasil — "Berapa rata-rata revenue per transaksi untuk setiap region di bulan Februari dua ribu dua puluh lima?"
# ✅ Q156: Training berhasil — "Tampilkan revenue untuk tiap-tiap produk di area AREA 1 pada bulan Desember dua ribu dua puluh empat."
# ✅ Q157: Training berhasil — "Bagaimana perkembangan jumlah transaksi per bulan dari Desember dua ribu dua puluh empat hingga Maret dua ribu dua puluh lima?"
# ✅ Q158: Training berhasil — "Berapa taker_uniq_all untuk masing-masing channel_name di bulan Januari dua ribu dua puluh lima?"
# ✅ Q159: Training berhasil — "Tampilkan perbandingan revenue dan transaksi di seluruh region pada bulan Februari dua ribu dua puluh lima."
# ✅ Q160: Training berhasil — "Bandingkan total revenue antara channel DigiPos dan MyTelkomsel selama bulan Januari dua ribu dua puluh lima."
# ✅ Q161: Training berhasil — "Tampilkan total transaksi per region untuk bulan Maret dua ribu dua puluh lima."
# ✅ Q162: Training berhasil — "Berapa total revenue dan jumlah taker_uniq_all dari produk NonRGB ATL 2GB 3Hari Rp5K selama bulan Februari dua ribu dua puluh lima?"
# ✅ Q163: Training berhasil — "Berapa revenue dari masing-masing campaign_initiatives pada bulan Desember dua ribu dua puluh empat?"
# ✅ Q164: Training berhasil — "Tampilkan total revenue dari produk-produk dalam channel DigiPos untuk bulan Januari dua ribu dua puluh lima."
# ✅ Q165: Training berhasil — "Berapa revenue rata-rata per channel_name di bulan Februari dua ribu dua puluh lima?"
# ✅ Q166: Training berhasil — "Bagaimana total revenue per region selama bulan Januari 2025?"
# ✅ Q167: Training berhasil — "Berapa jumlah transaksi masing-masing area pada bulan Desember 2024?"
# ✅ Q168: Training berhasil — "Apa saja nilai revenue dan jumlah pengguna unik dari masing-masing channel pada bulan Februari 2025?"
# ✅ Q169: Training berhasil — "Tampilkan perbandingan revenue tiap region antara bulan Desember 2024 dan Januari 2025"
# ✅ Q170: Training berhasil — "Bagaimana perubahan jumlah taker tiap area dari bulan Januari ke Februari 2025?"
# ✅ Q171: Training berhasil — "Tampilkan perbandingan transaksi untuk masing-masing channel di bulan Januari dan Februari 2025"
# ✅ Q172: Training berhasil — "Berapa revenue, trx, dan taker per region sepanjang Maret 2025?"
# ✅ Q173: Training berhasil — "Tampilkan ringkasan revenue per payment method selama bulan Januari 2025"
# ✅ Q174: Training berhasil — "Perbandingan revenue antara area AREA 1 dan AREA 2 selama bulan Februari 2025"
# ✅ Q175: Training berhasil — "Tampilkan total transaksi per produk untuk bulan Desember 2024"
# ✅ Q176: Training berhasil — "Apa saja channel dengan revenue tertinggi pada bulan Januari 2025?"
# ✅ Q177: Training berhasil — "Bandingkan revenue dari campaign Farming Sachet dan Farming Mini Pack di bulan Maret 2025"
# ✅ Q178: Training berhasil — "Tampilkan region dengan taker terbanyak selama Januari 2025"
# ✅ Q179: Training berhasil — "Berapa revenue dan jumlah transaksi dari tiap area selama Februari 2025?"
# ✅ Q180: Training berhasil — "Tampilkan 10 produk dengan revenue tertinggi pada bulan Desember 2024"
# ✅ Q181: Training berhasil — "Perbandingan transaksi antar channel selama bulan Januari 2025"
# ✅ Q182: Training berhasil — "Bagaimana tren revenue bulanan untuk channel UMB dari Desember 2024 sampai Maret 2025?"
# ✅ Q183: Training berhasil — "Apa saja area dengan transaksi lebih dari 5000 di bulan Januari 2025?"
# ✅ Q184: Training berhasil — "Tampilkan summary revenue dan taker tiap channel untuk kampanye Farming Sachet"
# ✅ Q185: Training berhasil — "Berapa total revenue dan transaksi per payment method sepanjang bulan Februari 2025?"
# ✅ Q186: Training berhasil — "Bagaimana pertumbuhan revenue bulan ke bulan per region dari Desember 2024 ke Januari 2025?"
# ✅ Q187: Training berhasil — "Bagaimana perubahan taker unik untuk setiap area dari Januari ke Februari 2025?"
# ✅ Q188: Training berhasil — "Tampilkan rasio revenue per transaksi untuk tiap region sepanjang Februari 2025"
# ✅ Q189: Training berhasil — "Apa saja perbedaan revenue untuk masing-masing area antara bulan Januari dan Maret 2025?"
# ✅ Q190: Training berhasil — "Channel apa yang mengalami peningkatan transaksi dari Desember 2024 ke Januari 2025?"
# ✅ Q191: Training berhasil — "Tampilkan top 5 region dengan rasio revenue/taker tertinggi bulan Januari 2025"
# ✅ Q192: Training berhasil — "Apa saja perbedaan performa revenue dan trx antar payment method di Februari 2025?"
# ✅ Q193: Training berhasil — "Tampilkan revenue untuk setiap channel selama 4 bulan terakhir"
# ✅ Q194: Training berhasil — "Bagaimana tren revenue per area untuk kampanye Farming Sachet dari Desember 2024 sampai Maret 2025?"
# ✅ Q195: Training berhasil — "Berapa kontribusi revenue masing-masing area terhadap total nasional bulan Januari 2025?"
# ✅ Q196: Training berhasil — "Apa saja perbedaan revenue dari channel UMB antar bulan dari Desember 2024 sampai Maret 2025?"
# ✅ Q197: Training berhasil — "Tampilkan taker, trx, dan revenue untuk tiap campaign di bulan Februari 2025"
# ✅ Q198: Training berhasil — "Bagaimana perbandingan jumlah transaksi dari tiap region antara Februari dan Maret 2025?"
# ✅ Q199: Training berhasil — "Tampilkan metrik performa (revenue, trx, taker) per channel untuk bulan Desember 2024"
# ✅ Q200: Training berhasil — "Berapa rata-rata revenue per taker di setiap area selama Januari 2025?"
# ✅ Q201: Training berhasil — "Tampilkan ranking produk berdasarkan revenue bulan Februari 2025"
# ✅ Q202: Training berhasil — "Bagaimana perubahan revenue pada tiap campaign dari Januari ke Februari 2025?"
# ✅ Q203: Training berhasil — "Channel mana yang mengalami penurunan revenue di bulan Maret 2025 dibandingkan Februari?"
# ✅ Q204: Training berhasil — "Apa rasio transaksi per taker untuk tiap region selama Maret 2025?"
# ✅ Q205: Training berhasil — "Bandingkan revenue produk Farming Mini Pack antar bulan Januari dan Maret 2025"
# ✅ Q206: Training berhasil — "Berapa total taker dan revenue untuk payment method terbanyak di bulan Januari 2025?"
# ✅ Q207: Training berhasil — "Apa saja channel dengan rata-rata revenue per transaksi tertinggi sepanjang Februari 2025?"
# ✅ Q208: Training berhasil — "Tampilkan kontribusi masing-masing produk terhadap total revenue bulan Maret 2025"
# ✅ Q209: Training berhasil — "Bandingkan revenue antar region yang memiliki nama mengandung kata 'Jabotabek' bulan Januari 2025"
# ✅ Q210: Training berhasil — "Tampilkan pertumbuhan revenue bulanan per channel selama periode Desember 2024 sampai Maret 2025"
# ✅ Q211: Training berhasil — "Bagaimana perbandingan total revenue antara bulan Desember 2024 dan Januari 2025?"
# ✅ Q212: Training berhasil — "Tampilkan total taker unik untuk masing-masing region selama bulan Februari 2025"
# ✅ Q213: Training berhasil — "Berapa jumlah transaksi per metode pembayaran di bulan Januari 2025?"
# ✅ Q214: Training berhasil — "Bagaimana distribusi revenue untuk setiap area di bulan Desember 2024?"
# ✅ Q215: Training berhasil — "Tampilkan perbandingan jumlah transaksi antara channel DigiPos dan MyTelkomsel di bulan Januari 2025"
# ✅ Q216: Training berhasil — "Berapa total revenue yang dihasilkan untuk masing-masing channel selama bulan Maret 2025?"
# ✅ Q217: Training berhasil — "Bandingkan jumlah pengguna unik di bulan Januari dan Februari 2025 untuk seluruh region"
# ✅ Q218: Training berhasil — "Tampilkan total transaksi yang dilakukan di setiap area selama bulan Februari 2025"
# ✅ Q219: Training berhasil — "Berapa total revenue yang diperoleh dari campaign Farming Sachet di setiap channel?"
# ✅ Q220: Training berhasil — "Bagaimana pertumbuhan revenue dari bulan Desember 2024 ke Januari 2025 di setiap region?"
# ✅ Q221: Training berhasil — "Berapa transaksi yang dilakukan di channel UMB untuk tiap bulan dari Desember 2024 sampai Maret 2025?"
# ✅ Q222: Training berhasil — "Tampilkan jumlah transaksi berdasarkan campaign di bulan Januari 2025"
# ✅ Q223: Training berhasil — "Bagaimana perbandingan revenue berdasarkan metode pembayaran di bulan Februari 2025?"
# ✅ Q224: Training berhasil — "Berapa rata-rata revenue per transaksi untuk setiap channel di bulan Maret 2025?"
# ✅ Q225: Training berhasil — "Tampilkan jumlah pengguna unik untuk setiap produk komersial di bulan Desember 2024"
# ✅ Q226: Training berhasil — "Berapa total transaksi di setiap region selama bulan Januari 2025?"
# ✅ Q227: Training berhasil — "Bandingkan jumlah transaksi per area di bulan Februari dan Maret 2025"
# ✅ Q228: Training berhasil — "Tampilkan revenue tertinggi untuk setiap area di bulan Januari 2025"
# ✅ Q229: Training berhasil — "Berapa total pengguna unik berdasarkan channel di bulan Maret 2025?"
# ✅ Q230: Training berhasil — "Tampilkan jumlah transaksi untuk tiap produk selama bulan Januari 2025"
# ✅ Q231: Training berhasil — "Bagaimana total revenue tiap region di bulan Desember 2024 dan Januari 2025?"
# ✅ Q232: Training berhasil — "Tampilkan metode pembayaran dengan revenue tertinggi di bulan Februari 2025"
# ✅ Q233: Training berhasil — "Berapa rata-rata revenue per transaksi untuk masing-masing region di bulan Maret 2025?"
# ✅ Q234: Training berhasil — "Bandingkan jumlah transaksi dan pengguna unik per area pada bulan Januari 2025"
# ✅ Q235: Training berhasil — "Tampilkan total revenue berdasarkan kombinasi campaign dan channel di bulan Februari 2025"
# ✅ Q236: Training berhasil — "Berapa persen kenaikan revenue di setiap area dari Januari 2025 ke Februari 2025?"
# ✅ Q237: Training berhasil — "Bagaimana perubahan jumlah taker di setiap channel dari Februari 2025 ke Maret 2025?"
# ✅ Q238: Training berhasil — "Apa rasio revenue terhadap transaksi di setiap region untuk bulan Januari 2025 dan Februari 2025?"
# ✅ Q239: Training berhasil — "Tampilkan pertumbuhan transaksi per area dari Desember 2024 ke Januari 2025 dalam persen"
# ✅ Q240: Training berhasil — "Berapa revenue total dan rata-rata transaksi di tiap channel selama bulan Maret 2025?"
# ✅ Q241: Training berhasil — "Bandingkan jumlah taker dan revenue produk RGB ATL 24GB 15Hari Rp41K antara Januari 2025 dan Februari 2025"
# ✅ Q242: Training berhasil — "Apa tren revenue produk RGB ATL 24GB 15Hari Rp41K dari Desember 2024 hingga Maret 2025?"
# ✅ Q243: Training berhasil — "Tampilkan revenue dan jumlah taker setiap region selama Februari 2025 dan Maret 2025"
# ✅ Q244: Training berhasil — "Bandingkan jumlah transaksi produk NonRGB ATL 12GB 7Hari Rp23K antar channel selama Januari 2025 dan Februari 2025"
# ✅ Q245: Training berhasil — "Berapa rata-rata revenue per taker untuk setiap region pada Februari 2025?"
# ✅ Q246: Training berhasil — "Apa persentase pertumbuhan taker per channel dari Januari 2025 ke Februari 2025?"
# ✅ Q247: Training berhasil — "Bandingkan revenue per campaign initiative antara Januari 2025 dan Februari 2025"
# ✅ Q248: Training berhasil — "Berapa rata-rata transaksi per taker untuk produk RGB ATL 24GB 15Hari Rp41K di bulan Februari 2025?"
# ✅ Q249: Training berhasil — "Bagaimana distribusi revenue antara channel UMB dan 05.DigiPos di bulan Maret 2025?"
# ✅ Q250: Training berhasil — "Apa pertumbuhan revenue area per bulan dari Desember 2024 sampai Maret 2025?"
# ✅ Q251: Training berhasil — "Berapa total transaksi seluruh produk di channel UMB selama Februari 2025?"
# ✅ Q252: Training berhasil — "Bandingkan rasio revenue/taker antara area AREA 1 dan AREA 2 untuk bulan Januari 2025"
# ✅ Q253: Training berhasil — "Tampilkan pertumbuhan revenue channel UMB dari Januari ke Februari 2025 dalam persen"
# ✅ Q254: Training berhasil — "Apa tren jumlah taker per region dari Desember 2024 hingga Maret 2025?"
# ✅ Q255: Training berhasil — "Bagaimana rasio revenue/trx per produk pada Februari 2025?"
# ✅ Q256: Training berhasil — "Berapa pertumbuhan taker untuk campaign initiative tertentu antara Januari dan Februari 2025?"
# ✅ Q257: Training berhasil — "Berapa total revenue semua region di bulan Desember 2024?"
# ✅ Q258: Training berhasil — "Berapa total revenue di seluruh region pada bulan Januari 2025?"
# ✅ Q259: Training berhasil — "Bagaimana perbandingan jumlah transaksi antara bulan Desember 2024 dan Januari 2025 untuk setiap area?"
# ✅ Q260: Training berhasil — "Tampilkan total revenue dari setiap channel pada bulan Februari 2025"
# ✅ Q261: Training berhasil — "Berapa total transaksi yang dilakukan menggunakan metode pembayaran BALANCE pada bulan Maret 2025 di setiap region?"
# ✅ Q262: Training berhasil — "Bandingkan revenue per region antara bulan Januari 2025 dan Februari 2025"
# ✅ Q263: Training berhasil — "Tampilkan taker unik untuk produk "NonRGB ATL 12GB 7Hari Rp23K" di setiap area"
# ✅ Q264: Training berhasil — "Berapa transaksi dan revenue pada tanggal dua puluh lima Desember dua ribu dua puluh empat?"
# ✅ Q265: Training berhasil — "Tampilkan revenue dari setiap campaign initiative pada bulan Januari 2025"
# ✅ Q266: Training berhasil — "Berapa total revenue dan transaksi untuk area AREA 2 pada bulan Desember 2024?"
# ✅ Q267: Training berhasil — "Tampilkan jumlah transaksi per channel pada tanggal satu Januari dua ribu dua puluh lima"
# ✅ Q268: Training berhasil — "Bandingkan jumlah pengguna unik antara bulan Januari dan Februari 2025 di tiap region"
# ✅ Q269: Training berhasil — "Berapa total revenue dari campaign Farming Sachet selama bulan Januari 2025?"
# ✅ Q270: Training berhasil — "Tampilkan data transaksi dan revenue untuk semua area pada tanggal tiga Maret dua ribu dua puluh lima"
# ✅ Q271: Training berhasil — "Berapa jumlah transaksi dan revenue dari channel MyTelkomsel selama bulan Februari 2025?"
# ✅ Q272: Training berhasil — "Tampilkan perbandingan jumlah taker unik antara channel DigiPos dan UMB selama Januari 2025"
# ✅ Q273: Training berhasil — "Berapa transaksi dan revenue pada tanggal tiga puluh satu Desember dua ribu dua puluh empat di setiap area?"
# ✅ Q274: Training berhasil — "Tampilkan jumlah revenue dari tiap metode pembayaran pada bulan Januari 2025"
# ✅ Q275: Training berhasil — "Berapa revenue harian untuk channel UMB selama bulan Februari 2025?"
# ✅ Q276: Training berhasil — "Bandingkan revenue channel DigiPos antara bulan Januari dan Februari 2025"
# ✅ Q277: Training berhasil — "Berapa total taker unik untuk produk "NonRGB ATL 2GB 3Hari Rp5K" sepanjang bulan Maret 2025?"
# ✅ Q278: Training berhasil — "Tampilkan revenue mingguan untuk area AREA 3 selama Januari 2025"
# ✅ Q279: Training berhasil — "Berapa rata-rata transaksi harian pada bulan Februari 2025 di region Sumbagut?"
# ✅ Q280: Training berhasil — "Bandingkan jumlah transaksi antar channel selama bulan Desember 2024"
# ✅ Q281: Training berhasil — "Berapa revenue untuk channel UMB pada tanggal dua belas Januari dua ribu dua puluh lima?"
# ✅ Q282: Training berhasil — "Tampilkan taker unik harian untuk produk "NonRGB ATL 12GB 7Hari Rp23K" selama Januari 2025"
# ✅ Q283: Training berhasil — "Berapa rata-rata revenue per transaksi untuk setiap channel pada bulan Desember 2024?"
# ✅ Q284: Training berhasil — "Tampilkan total transaksi untuk masing-masing region pada bulan Januari 2025 dan urutkan dari yang terbanyak."
# ✅ Q285: Training berhasil — "Berapa total revenue untuk masing-masing metode pembayaran selama bulan Februari 2025?"
# ✅ Q286: Training berhasil — "Tampilkan produk dengan jumlah taker terbanyak pada bulan Januari 2025."
# ✅ Q287: Training berhasil — "Berapa total revenue dan transaksi yang terjadi di area AREA 3 sepanjang bulan Desember 2024?"
# ✅ Q288: Training berhasil — "Tampilkan perbandingan jumlah transaksi antara bulan Januari dan Februari 2025 untuk campaign "Farming Sachet"."
# ✅ Q289: Training berhasil — "Berapa rata-rata revenue per taker untuk masing-masing region selama bulan Desember 2024?"
# ✅ Q290: Training berhasil — "Tampilkan channel dengan revenue tertinggi di bulan Februari 2025."
# ✅ Q291: Training berhasil — "Berapa total transaksi yang terjadi pada semua area untuk campaign "Farming Sachet" selama bulan Januari 2025?"
# ✅ Q292: Training berhasil — "Tampilkan kombinasi channel dan produk dengan revenue terbesar di bulan Desember 2024."
# ✅ Q293: Training berhasil — "Berapa rata-rata transaksi harian di bulan Januari 2025?"
# ✅ Q294: Training berhasil — "Tampilkan jumlah taker unik untuk setiap region pada bulan Desember 2024."
# ✅ Q295: Training berhasil — "Bandingkan revenue antara channel DigiPos dan MyTelkomsel di bulan Januari 2025."
# ✅ Q296: Training berhasil — "Berapa rata-rata revenue per transaksi untuk campaign "Farming Sachet"?"
# ✅ Q297: Training berhasil — "Tampilkan pertumbuhan jumlah transaksi dari Desember 2024 ke Januari 2025 untuk setiap channel."
# ✅ Q298: Training berhasil — "Berapa total revenue untuk setiap produk di bulan Januari 2025?"
# ✅ Q299: Training berhasil — "Tampilkan tiga area dengan revenue tertinggi di bulan Februari 2025."
# ✅ Q300: Training berhasil — "Berapa total taker unik untuk setiap campaign sepanjang bulan Desember 2024?"
# ✅ Q301: Training berhasil — "Tampilkan produk dengan rasio revenue per transaksi tertinggi di bulan Januari 2025."
# ✅ Q302: Training berhasil — "Berapa banyak revenue yang dihasilkan oleh metode pembayaran BALANCE di bulan Februari 2025?"
# ✅ Q303: Training berhasil — "Tampilkan perbandingan total revenue untuk setiap region antara Januari dan Februari 2025."
# ✅ Q304: Training berhasil — "Berapa jumlah transaksi tertinggi yang dilakukan oleh satu channel di bulan Desember 2024?"
# ✅ Q305: Training berhasil — "Tampilkan rata-rata revenue per hari selama bulan Februari 2025."
# ✅ Q306: Training berhasil — "Berapa total transaksi untuk masing-masing produk pada channel UMB selama bulan Januari 2025?"
# ✅ Q307: Training berhasil — "Tampilkan kontribusi revenue masing-masing channel terhadap total revenue pada bulan Januari 2025."
# ✅ Q308: Training berhasil — "Apa metode pembayaran paling sering digunakan di bulan Januari 2025?"
# ✅ Q309: Training berhasil — "Berapa total revenue dari semua produk yang namanya mengandung kata 'NonRGB'?"
# ✅ Q310: Training berhasil — "Tampilkan 3 area teratas berdasarkan jumlah transaksi sepanjang tahun 2024"
# ✅ Q311: Training berhasil — "Berapa rata-rata revenue per transaksi di bulan Februari 2025?"
# ✅ Q312: Training berhasil — "Tampilkan kombinasi area dan channel dengan revenue di atas 10 juta di bulan Desember 2024"
# ✅ Q313: Training berhasil — "Berapa kontribusi channel DigiPos terhadap total revenue nasional sepanjang Januari 2025?"
# ✅ Q314: Training berhasil — "Berapa jumlah produk unik yang dijual melalui channel UMB selama Februari 2025?"
# ✅ Q315: Training berhasil — "Apa nama campaign yang menghasilkan transaksi tertinggi di area AREA 2 pada Januari 2025?"
# ✅ Q316: Training berhasil — "Tampilkan 5 produk dengan revenue tertinggi sepanjang Februari 2025"
# ✅ Q317: Training berhasil — "Berapa rata-rata pengguna unik per hari di bulan Januari 2025?"
# ✅ Q318: Training berhasil — "Berapa total revenue untuk produk dengan nama mengandung '23K' pada bulan Desember 2024?"
# ✅ Q319: Training berhasil — "Tampilkan kombinasi channel dan payment method dengan revenue tertinggi pada Februari 2025"
# ✅ Q320: Training berhasil — "Berapa persen revenue dari produk 'NonRGB ATL 12GB 7Hari Rp23K' terhadap total revenue Januari 2025?"
# ✅ Q321: Training berhasil — "Apa saja metode pembayaran yang digunakan di region Kalimantan pada Februari 2025?"
# ✅ Q322: Training berhasil — "Berapa rata-rata transaksi harian di region Sulawesi selama Desember 2024?"
# ✅ Q323: Training berhasil — "Channel apa yang memiliki pengguna unik terbanyak sepanjang bulan Februari 2025?"
# ✅ Q324: Training berhasil — "Berapa total revenue untuk campaign 'Farming Sachet' di seluruh region Jawa pada Januari 2025?"
# ✅ Q325: Training berhasil — "Tampilkan channel dengan nilai transaksi nol selama Februari 2025"
# ✅ Q326: Training berhasil — "Apa 3 kombinasi area dan produk dengan pengguna unik tertinggi sepanjang Januari 2025?"
# ✅ Q327: Training berhasil — "Berapa total transaksi yang dilakukan oleh semua campaign di area AREA 3 selama Desember 2024?"
# ✅ Q328: Training berhasil — "Tampilkan produk dengan revenue tertinggi per region untuk Januari 2025"
# ✅ Q329: Training berhasil — "Apa channel dengan rasio revenue per trx tertinggi selama Februari 2025?"
# ✅ Q330: Training berhasil — "Berapa jumlah transaksi untuk setiap metode pembayaran pada bulan Desember 2024?"
# ✅ Q331: Training berhasil — "Tampilkan revenue dan trx harian untuk produk 'NonRGB ATL 12GB 7Hari Rp23K' di bulan Januari 2025"
# ✅ Q332: Training berhasil — "Apa kombinasi region dan campaign yang menghasilkan revenue di bawah 1 juta di Februari 2025?"
# ✅ Q333: Training berhasil — "Berapa variasi produk komersial yang terjual di bulan Desember 2024?"
# ✅ Q334: Training berhasil — "Sebutkan 5 channel dengan revenue tertinggi sepanjang tahun 2024?"
# ✅ Q335: Training berhasil — "Berapa rata-rata revenue per transaksi pada bulan Januari 2025?"
# ✅ Q336: Training berhasil — "Berapa metode pembayaran unik yang digunakan selama bulan Februari 2025?"
# ✅ Q337: Training berhasil — "Berapa total pengguna unik untuk masing-masing area sepanjang Desember 2024?"
# ✅ Q338: Training berhasil — "Berapa distribusi transaksi per region untuk bulan Januari 2025?"
# ✅ Q339: Training berhasil — "Berapa total revenue dari setiap channel pada Februari 2025?"
# ✅ Q340: Training berhasil — "Sebutkan 3 produk dengan jumlah transaksi tertinggi pada Januari 2025"
# ✅ Q341: Training berhasil — "Berapa rata-rata revenue per user untuk setiap region di bulan Maret 2025?"
# ✅ Q342: Training berhasil — "Apa saja campaign yang aktif di bulan Desember 2024?"
# ✅ Q343: Training berhasil — "Berapa revenue harian rata-rata untuk channel MyTelkomsel di bulan Januari 2025?"
# ✅ Q344: Training berhasil — "Berapa revenue mingguan rata-rata untuk area AREA 2 pada Februari 2025?"
# ✅ Q345: Training berhasil — "Berapa jumlah transaksi dan revenue untuk setiap kombinasi area dan region di bulan Desember 2024?"
# ✅ Q346: Training berhasil — "Channel mana yang menghasilkan revenue tertinggi di region Kalimantan pada Maret 2025?"
# ✅ Q347: Training berhasil — "Berapa revenue harian tertinggi di bulan Januari 2025?"
# ✅ Q348: Training berhasil — "Berapa rata-rata transaksi per produk pada bulan Februari 2025?"
# ✅ Q349: Training berhasil — "Berapa banyak channel yang digunakan di region Sulawesi sepanjang Maret 2025?"
# ✅ Q350: Training berhasil — "Berapa total transaksi untuk masing-masing campaign di bulan Januari 2025?"
# ✅ Q351: Training berhasil — "Berapa rasio revenue terhadap jumlah pengguna unik untuk setiap channel di bulan Februari 2025?"
# ✅ Q352: Training berhasil — "Berapa produk yang memiliki lebih dari 1000 transaksi pada Desember 2024?"
# ✅ Q353: Training berhasil — "Berapa total pengguna unik dan transaksi untuk channel UMB selama Januari 2025?"
# ✅ Q354: Training berhasil — "Region mana yang memiliki revenue tertinggi di bulan Februari 2025?"
# ✅ Q355: Training berhasil — "Area mana yang memiliki jumlah transaksi paling rendah di bulan Desember 2024?"
# ✅ Q356: Training berhasil — "Berapa revenue dan jumlah pengguna unik untuk produk "NonRGB ATL 10GB 30Hari Rp45K" sepanjang Januari 2025?"
# ✅ Q357: Training berhasil — "Berapa rasio transaksi terhadap revenue untuk setiap metode pembayaran di bulan Maret 2025?"
# ✅ Q358: Training berhasil — "Tunjukkan total revenue dan transaksi untuk masing-masing metode pembayaran selama Februari 2025"
# ✅ Q359: Training berhasil — "Sebutkan nama produk dengan performa revenue terbaik di Januari 2025"
# ✅ Q360: Training berhasil — "Tampilkan distribusi transaksi berdasarkan channel untuk region 07.Jabar sepanjang Desember 2024"
# ✅ Q361: Training berhasil — "Identifikasi area dengan revenue paling besar di bulan Maret 2025"
# ✅ Q362: Training berhasil — "Cari tahu produk mana saja yang digunakan di channel MyTelkomsel selama Januari 2025"
# ✅ Q363: Training berhasil — "Tampilkan kombinasi area dan campaign_initiatives dengan transaksi tertinggi di Desember 2024"
# ✅ Q364: Training berhasil — "Identifikasi metode pembayaran yang menghasilkan revenue terbanyak di bulan Februari 2025"
# ✅ Q365: Training berhasil — "Tampilkan revenue per channel di region 09.Jatim selama Januari 2025"
# ✅ Q366: Training berhasil — "Tunjukkan channel dengan pengguna unik terbanyak selama Maret 2025"
# ✅ Q367: Training berhasil — "Temukan 3 kombinasi produk dan campaign yang paling sering muncul sepanjang Februari 2025"
# ✅ Q368: Training berhasil — "Bandingkan total transaksi antara channel UMB dan channel MyTelkomsel di bulan Desember 2024"
# ✅ Q369: Training berhasil — "Tampilkan total revenue dan pengguna unik per produk untuk bulan Januari 2025"
# ✅ Q370: Training berhasil — "Identifikasi channel yang hanya digunakan di satu region selama Februari 2025"
# ✅ Q371: Training berhasil — "Sebutkan nama-nama produk yang tidak memiliki transaksi selama Maret 2025"
# ✅ Q372: Training berhasil — "Tampilkan 5 area dengan pengguna unik paling sedikit di bulan Januari 2025"
# ✅ Q373: Training berhasil — "Identifikasi channel dengan selisih revenue tertinggi dibanding bulan sebelumnya (Februari ke Maret 2025)"
# ...
# Add of existing embedding ID: c6b5d07a-ea21-5425-a8bd-741eccf3b0ed-sql
# Insert of existing embedding ID: c6b5d07a-ea21-5425-a8bd-741eccf3b0ed-sql
# Add of existing embedding ID: a0c8ca19-757b-560f-999e-bb33c80132b6-sql
# Insert of existing embedding ID: a0c8ca19-757b-560f-999e-bb33c80132b6-sql
# ✅ Q405: Training berhasil — "Tampilkan 5 kombinasi region dan produk dengan revenue terbesar di Februari 2025"
# ✅ Q406: Training berhasil — "Sebutkan seluruh kombinasi area dan channel yang menghasilkan revenue di bawah 10 juta pada Maret 2025"
# ✅ Q407: Training berhasil — "Identifikasi campaign yang menghasilkan revenue di atas rata-rata di bulan Januari 2025"
# ✅ Q408: Training berhasil — "Tunjukkan region dengan revenue tertinggi selama bulan Desember 2024"
# ✅ Q409: Training berhasil — "Sebutkan tiga produk dengan jumlah transaksi terbanyak di Januari 2025"
# ✅ Q410: Training berhasil — "Saluran penjualan apa yang memiliki taker unik tertinggi sepanjang Maret 2025?"
# ✅ Q411: Training berhasil — "Apa saja metode pembayaran yang digunakan di bulan Februari 2025?"
# ✅ Q412: Training berhasil — "Tampilkan 5 area dengan revenue terendah selama bulan Desember 2024"
# ✅ Q413: Training berhasil — "Di bulan Januari 2025, produk apa yang menghasilkan revenue paling besar?"
# ✅ Q414: Training berhasil — "Mana yang lebih tinggi, total transaksi di Februari atau Maret 2025?"
# ✅ Q415: Training berhasil — "Sebutkan nama campaign yang dijalankan di region Kalimantan pada bulan Maret 2025"
# ✅ Q416: Training berhasil — "Apa metode pembayaran paling populer sepanjang Desember 2024?"
# ✅ Q417: Training berhasil — "Di bulan Februari 2025, channel penjualan apa yang menyumbang revenue terbanyak?"
# ✅ Q418: Training berhasil — "Tampilkan perbandingan total taker di Januari dan Februari 2025 untuk channel MyTelkomsel"
# ✅ Q419: Training berhasil — "Apa area dengan pertumbuhan transaksi paling tinggi antara Januari dan Februari 2025?"
# ✅ Q420: Training berhasil — "Produk apa yang muncul di seluruh bulan dari Desember 2024 hingga Maret 2025?"
# ✅ Q421: Training berhasil — "Berikan total revenue per region selama bulan Februari 2025"
# ✅ Q422: Training berhasil — "Tampilkan lima kombinasi produk dan channel dengan transaksi tertinggi sepanjang Januari 2025"
# ✅ Q423: Training berhasil — "Apa nama produk yang hanya dijual melalui channel UMB selama Maret 2025?"
# ✅ Q424: Training berhasil — "Sebutkan perbedaan revenue antara campaign Farming Sachet dan campaign lain di bulan Desember 2024"
# ✅ Q425: Training berhasil — "Berapa rata-rata revenue harian di bulan Februari 2025?"
# ✅ Q426: Training berhasil — "Channel mana yang mengalami penurunan transaksi dari Januari ke Februari 2025?"
# ✅ Q427: Training berhasil — "Apa produk dengan pertumbuhan revenue tertinggi antara Januari dan Februari 2025?"
# ✅ Q428: Training berhasil — "Tampilkan total transaksi berdasarkan metode pembayaran sepanjang bulan Maret 2025"
# ✅ Q429: Training berhasil — "Berapa jumlah taker yang membeli produk NonRGB ATL 2GB 3Hari Rp5K selama Februari 2025?"
# ✅ Q430: Training berhasil — "Campaign apa yang aktif di lebih dari 5 area pada bulan Januari 2025?"
# ✅ Q431: Training berhasil — "Apa region dengan variasi channel terbanyak selama Maret 2025?"
# ✅ Q432: Training berhasil — "Tampilkan 3 kombinasi region dan metode pembayaran dengan revenue tertinggi di Januari 2025"
# ✅ Q433: Training berhasil — "Tampilkan total revenue dan jumlah transaksi per channel untuk bulan Januari 2025"
# ✅ Q434: Training berhasil — "Tampilkan pengguna unik dan total transaksi per area di bulan Desember 2024"
# ✅ Q435: Training berhasil — "Bandingkan revenue dan jumlah transaksi antara channel DigiPos dan MyTelkomsel sepanjang tahun 2024"
# ✅ Q436: Training berhasil — "Tampilkan 5 produk dengan revenue tertinggi selama Maret 2025 beserta jumlah transaksi"
# ✅ Q437: Training berhasil — "Bandingkan rata-rata revenue per transaksi per region untuk bulan Februari 2025"
# ✅ Q438: Training berhasil — "Tampilkan data revenue, taker unik, dan transaksi per metode pembayaran di bulan Januari 2025"
# ✅ Q439: Training berhasil — "Berapa rata-rata taker unik harian per channel sepanjang Februari 2025?"
# ✅ Q440: Training berhasil — "Tampilkan kontribusi masing-masing area terhadap total revenue nasional di bulan Desember 2024"
# ✅ Q441: Training berhasil — "Tampilkan jumlah transaksi per tanggal untuk produk "NonRGB ATL 2GB 3Hari Rp5K" selama Januari 2025"
# ✅ Q442: Training berhasil — "Tampilkan 3 channel dengan pertumbuhan revenue tertinggi dari Desember 2024 ke Januari 2025"
# ✅ Q443: Training berhasil — "Tampilkan total revenue dan jumlah pengguna unik per region untuk bulan Maret 2025"
# ✅ Q444: Training berhasil — "Tampilkan rasio antara revenue dan taker unik per area sepanjang Februari 2025"
# ✅ Q445: Training berhasil — "Apa saja 5 campaign dengan revenue tertinggi sepanjang periode data tersedia?"
# ✅ Q446: Training berhasil — "Tampilkan tren harian revenue untuk area "AREA 2" selama Desember 2024"
# ✅ Q447: Training berhasil — "Bandingkan jumlah transaksi dan revenue antar metode pembayaran di bulan Maret 2025"
# ✅ Q448: Training berhasil — "Berapa kontribusi channel UMB terhadap total transaksi nasional pada Januari 2025?"
# ✅ Q449: Training berhasil — "Tampilkan 5 region dengan taker terbanyak pada Februari 2025"
# ✅ Q450: Training berhasil — "Bandingkan revenue produk “NonRGB ATL 12GB 7Hari Rp23K” antara channel DigiPos dan MyTelkomsel di bulan Januari 2025"
# ✅ Q451: Training berhasil — "Berapa rata-rata revenue per transaksi untuk setiap campaign di Desember 2024?"
# ✅ Q452: Training berhasil — "Tampilkan kontribusi revenue per channel untuk produk “NonRGB ATL 2GB 3Hari Rp5K” di Januari 2025"
# ✅ Q453: Training berhasil — "Tampilkan total revenue dan jumlah transaksi untuk masing-masing channel sepanjang bulan Desember 2024"
# ✅ Q454: Training berhasil — "Bandingkan revenue dan jumlah pengguna unik per region untuk Januari dan Februari 2025"
# ✅ Q455: Training berhasil — "Tampilkan area dengan transaksi tertinggi dan jumlah revenue yang dihasilkan sepanjang kuartal pertama 2025"
# ✅ Q456: Training berhasil — "Berapa rata-rata revenue per transaksi untuk setiap channel pada bulan Februari 2025?"
# ✅ Q457: Training berhasil — "Tampilkan jumlah transaksi, revenue, dan taker unik per metode pembayaran sepanjang Maret 2025"
# ✅ Q458: Training berhasil — "Bandingkan revenue dari campaign berbeda di area AREA 1 sepanjang Desember 2024"
# ✅ Q459: Training berhasil — "Tampilkan tren pertumbuhan revenue harian sepanjang Januari 2025"
# ✅ Q460: Training berhasil — "Bandingkan rata-rata taker per hari di bulan Januari dan Februari 2025"
# ✅ Q461: Training berhasil — "Tampilkan region dengan rata-rata transaksi tertinggi per hari di bulan Februari 2025"
# ✅ Q462: Training berhasil — "Tampilkan perbandingan revenue dan transaksi antar channel DigiPos dan UMB sepanjang Januari 2025"
# ✅ Q463: Training berhasil — "Tampilkan kontribusi tiap produk terhadap total revenue bulan Desember 2024"
# ✅ Q464: Training berhasil — "Berapa rata-rata revenue per pengguna untuk channel MyTelkomsel sepanjang Januari 2025?"
# ✅ Q465: Training berhasil — "Tampilkan ranking region berdasarkan jumlah taker sepanjang Februari 2025"
# ✅ Q466: Training berhasil — "Apa saja campaign yang menghasilkan revenue di atas 1 miliar sepanjang Desember 2024?"
# ✅ Q467: Training berhasil — "Berapa jumlah transaksi dan revenue yang terjadi di tiap area pada bulan Januari 2025?"
# ✅ Q468: Training berhasil — "Tampilkan pertumbuhan revenue bulan ke bulan untuk channel DigiPos sepanjang periode data"
# ✅ Q469: Training berhasil — "Tampilkan produk yang paling banyak dibeli (berdasarkan trx) selama Maret 2025"
# ✅ Q470: Training berhasil — "Tampilkan nilai revenue dan transaksi masing-masing region selama bulan Februari 2025"
# ✅ Q471: Training berhasil — "Berapa kontribusi transaksi dari channel UMB terhadap total transaksi pada bulan Desember 2024?"
# ✅ Q472: Training berhasil — "Bandingkan total revenue masing-masing metode pembayaran sepanjang kuartal pertama 2025"
# ✅ Q473: Training berhasil — "Tampilkan produk dengan pertumbuhan revenue positif dari Desember 2024 ke Januari 2025"
# ✅ Q474: Training berhasil — "Tampilkan rata-rata transaksi harian per region selama bulan Januari 2025"
# ✅ Q475: Training berhasil — "Tampilkan channel dengan rata-rata pengguna terbanyak per hari di Februari 2025"
# ✅ Q476: Training berhasil — "Berapa total revenue, trx, dan pengguna unik yang dicatat untuk campaign Farming Sachet di Januari 2025?"
# ✅ Q477: Training berhasil — "Tampilkan ringkasan performa transaksi (trx, revenue, taker) untuk setiap produk di Desember 2024"
# ✅ Q478: Training berhasil — "Tampilkan total revenue dan jumlah transaksi untuk tiap channel pada bulan Januari 2025."
# ✅ Q479: Training berhasil — "Tampilkan rata-rata revenue per transaksi di tiap area sepanjang Februari 2025."
# ✅ Q480: Training berhasil — "Bandingkan jumlah transaksi dan pengguna unik per metode pembayaran untuk Maret 2025."
# ✅ Q481: Training berhasil — "Apa saja produk yang memiliki revenue tertinggi pada bulan Desember 2024?"
# ✅ Q482: Training berhasil — "Tampilkan total transaksi per region dan area pada Februari 2025."
# ✅ Q483: Training berhasil — "Tampilkan 5 channel dengan revenue tertinggi sepanjang periode data tersedia."
# ✅ Q484: Training berhasil — "Berapa rasio pengguna unik terhadap transaksi untuk setiap campaign sepanjang Januari 2025?"
# ✅ Q485: Training berhasil — "Tampilkan kontribusi revenue per produk untuk channel DigiPos selama Januari 2025."
# ✅ Q486: Training berhasil — "Apa saja 3 region dengan taker unik terbanyak pada bulan Februari 2025?"
# ✅ Q487: Training berhasil — "Berapa rata-rata revenue harian untuk channel MyTelkomsel selama Maret 2025?"
# ✅ Q488: Training berhasil — "Tampilkan revenue dan trx untuk produk “NonRGB ATL 2GB 3Hari Rp5K” per channel pada Desember 2024."
# ✅ Q489: Training berhasil — "Apa tren revenue harian selama bulan Januari 2025?"
# ✅ Q490: Training berhasil — "Bandingkan total revenue dan jumlah taker unik di setiap region untuk Desember 2024 dan Januari 2025."
# ✅ Q491: Training berhasil — "Berapa kontribusi masing-masing channel terhadap total revenue di bulan Maret 2025?"
# ✅ Q492: Training berhasil — "Tampilkan revenue per area dan campaign pada Januari 2025."
# ✅ Q493: Training berhasil — "Tampilkan pertumbuhan jumlah transaksi per channel antara Januari dan Februari 2025."
# ✅ Q494: Training berhasil — "Apa metode pembayaran paling populer di tiap region selama Maret 2025?"
# ✅ Q495: Training berhasil — "Tampilkan data harian revenue dan transaksi di bulan Desember 2024."
# ✅ Q496: Training berhasil — "Apa saja top 5 area dengan revenue tertinggi pada Februari 2025?"
# ✅ Q497: Training berhasil — "Tampilkan performa campaign "Farming Sachet" per channel di bulan Maret 2025."
# ✅ Q498: Training berhasil — "Tampilkan revenue per produk di channel UMB selama Februari 2025."
# ✅ Q499: Training berhasil — "Apa channel dengan revenue per transaksi tertinggi pada Januari 2025?"
# ✅ Q500: Training berhasil — "Bandingkan rata-rata pengguna unik per produk selama Januari 2025."
# ✅ Q501: Training berhasil — "Tampilkan 3 produk dengan taker unik terbanyak di bulan Maret 2025."
# ✅ Q502: Training berhasil — "Tampilkan distribusi revenue per metode pembayaran selama Januari 2025."
# ✅ Q503: Training berhasil — "Bagaimana perbandingan total revenue antara Januari dan Februari 2025?"
# ✅ Q504: Training berhasil — "Apa selisih jumlah transaksi antara bulan Desember 2024 dan Januari 2025?"
# ✅ Q505: Training berhasil — "Channel apa yang mengalami peningkatan revenue tertinggi dari Desember 2024 ke Januari 2025?"
# ✅ Q506: Training berhasil — "Region mana yang mengalami penurunan jumlah transaksi terbesar dari Januari ke Februari 2025?"
# ✅ Q507: Training berhasil — "Bagaimana pertumbuhan jumlah pengguna unik dari Desember 2024 ke Maret 2025?"
# ✅ Q508: Training berhasil — "Tampilkan perbandingan revenue produk "NonRGB ATL 2GB 3Hari Rp5K" di bulan Januari dan Februari 2025"
# ✅ Q509: Training berhasil — "Apa persentase perubahan revenue antara Februari dan Maret 2025?"
# ✅ Q510: Training berhasil — "Perbandingan jumlah transaksi berdasarkan channel di bulan Januari dan Februari 2025"
# ✅ Q511: Training berhasil — "Apakah ada region yang mengalami lonjakan pengguna unik di bulan Maret 2025 dibanding Januari 2025?"
# ✅ Q512: Training berhasil — "Bagaimana distribusi revenue di bulan Januari, Februari, dan Maret 2025 berdasarkan area?"
# ✅ Q513: Training berhasil — "Tampilkan jumlah transaksi dan revenue untuk Februari dan Maret 2025"
# ✅ Q514: Training berhasil — "Apakah channel MyTelkomsel memiliki pertumbuhan revenue dari Januari ke Februari 2025?"
# ✅ Q515: Training berhasil — "Tampilkan rata-rata revenue per transaksi per bulan dari Desember 2024 hingga Maret 2025"
# ✅ Q516: Training berhasil — "Bandingkan jumlah transaksi produk "NonRGB ATL 12GB 7Hari Rp23K" pada Desember 2024 dan Januari 2025"
# ✅ Q517: Training berhasil — "Apakah terjadi penurunan taker di channel UMB dari Desember ke Januari?"
# ✅ Q518: Training berhasil — "Bandingkan revenue untuk campaign "Farming Sachet" antara bulan Januari dan Februari 2025"
# ✅ Q519: Training berhasil — "Apa metode pembayaran yang mengalami peningkatan transaksi dari Februari ke Maret 2025?"
# ✅ Q520: Training berhasil — "Tampilkan tren total revenue berdasarkan channel dari Desember 2024 hingga Maret 2025"
# ✅ Q521: Training berhasil — "Bagaimana perubahan total taker per area dari Januari ke Maret 2025?"
# ✅ Q522: Training berhasil — "Tampilkan data pertumbuhan revenue dan transaksi dari Desember 2024 ke Januari 2025"
# ✅ Q523: Training berhasil — "Bagaimana perbandingan revenue antara bulan Desember 2024 dan Januari 2025 untuk setiap region?"
# ✅ Q524: Training berhasil — "Tampilkan pertumbuhan jumlah transaksi dari bulan Desember 2024 ke Januari 2025 di setiap area."
# ✅ Q525: Training berhasil — "Bandingkan total revenue antara bulan Januari dan Februari 2025 per channel."
# ✅ Q526: Training berhasil — "Tampilkan perubahan jumlah taker unik di masing-masing area antara Februari dan Maret 2025."
# ✅ Q527: Training berhasil — "Bandingkan revenue dan jumlah transaksi per region antara bulan Januari dan Februari 2025."
# ✅ Q528: Training berhasil — "Perlihatkan perubahan revenue per channel dari bulan Desember 2024 ke Januari 2025."
# ✅ Q529: Training berhasil — "Bagaimana perbandingan taker unik antara bulan Januari dan Februari 2025 berdasarkan metode pembayaran?"
# ✅ Q530: Training berhasil — "Tampilkan nilai revenue dan jumlah transaksi berdasarkan campaign untuk bulan Desember 2024 dan Januari 2025."
# ✅ Q531: Training berhasil — "Bandingkan revenue pada bulan Februari 2025 antara setiap area dan region."
# ✅ Q532: Training berhasil — "Tampilkan perubahan jumlah transaksi harian antara 1 Januari dan 1 Februari 2025."
# ✅ Q533: Training berhasil — "Bandingkan jumlah taker antara dua produk tertentu pada bulan Maret 2025."
# ✅ Q534: Training berhasil — "Tampilkan perbandingan revenue dan taker per channel untuk bulan Februari dan Maret 2025."
# ✅ Q535: Training berhasil — "Bagaimana tren revenue dari Desember 2024 hingga Maret 2025 untuk masing-masing area?"
# ✅ Q536: Training berhasil — "Perlihatkan perbandingan revenue dan jumlah transaksi untuk channel DigiPos dan UMB sepanjang Februari 2025."
# ✅ Q537: Training berhasil — "Bandingkan performa campaign Farming Sachet di Januari dan Februari 2025 dari sisi revenue dan taker."
# ✅ Q538: Training berhasil — "Bagaimana perubahan transaksi harian di bulan Desember 2024 untuk setiap region?"
# ✅ Q539: Training berhasil — "Tampilkan perbandingan revenue antar metode pembayaran untuk dua bulan terakhir."
# ✅ Q540: Training berhasil — "Perbandingan jumlah transaksi dan revenue berdasarkan area antara Januari dan Februari 2025."
# ✅ Q541: Training berhasil — "Bandingkan jumlah taker dan transaksi dari produk "NonRGB ATL 12GB 7Hari Rp23K" antara Desember dan Januari."
# ✅ Q542: Training berhasil — "Perlihatkan kontribusi masing-masing region terhadap total revenue di bulan Januari 2025 dan bandingkan dengan Februari."
